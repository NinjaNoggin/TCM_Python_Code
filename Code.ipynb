# %%
#!/bin/python3

#Print Hello World
print("Hello World!")
#Python can print using single or double quotes
print('Hello World!')

#Print using triple quotes for multi-line strings
print("""This string runs
multiple lines""")
# Out:
# Hello World!
# Hello World!
# This string runs
# multiple lines
